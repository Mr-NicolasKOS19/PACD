# %% [markdown]
# Aprendendo python
# Comandos e conceitos básicos

# %% [markdown]
# Operadores Aritimétricos - Exemplos
#
# Criar um programa que leia dois números floats e
# apresente o resultado das operaçõe:
# Adição,Subtração,Multiplocação,Divisão,Potenviação
# entre os mesmos

# %%
#Entradas dos dados
a=float(input("Informe o 1º número:"))
b=float(input("Informe o 2º número:"))
#Processamento dos dados
s=a+b
sub=a-b
m=a*b
d=a/b
p=a**b #Cálculo da potenciação - 'a' elevado a 'b'

#Saída dos resultados
print(f"{a} = {b} = {s}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Entradas dos dados
# ----> 2 a=float(input("Informe o 1º número:"))
#       3 b=float(input("Informe o 2º número:"))
#       4 #Processamento dos dados
#
# File c:\Users\LabInfo\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\LabInfo\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [raw]
# Exemplo: Resto inteiro de um divisão - Operador %
# Criar um código pytjon que leia um número inteiro e
# informe se ele é par ou ímpar

# %%
a=2025
print(a%2) #Retornará no valor 0 ou 1
# Out:
# 1

# %% [markdown]
# Exemplo de estrutura de decisão if:

# %%
n=2026

if n>0:
    print("Esse número é maior que zero")
elif n<0:
    print(f"O número é menor que zero")
else:
    print(f"o número é zero")
# Out:
# Esse número é maior que zero

# %%
12
# Out:
# 12
